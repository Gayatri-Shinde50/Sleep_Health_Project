# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("Sleep_health_and_lifestyle_dataset.csv",encoding='unicode_escape')
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.shape
# Out:
# (374, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155 entries, 3 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                155 non-null    int64
#  1   Gender                   155 non-null    object
#  2   Age                      155 non-null    int64
#  3   Occupation               155 non-null    object
#  4   Sleep Duration           155 non-null    float64
#  5   Quality of Sleep         155 non-null    int64
#  6   Physical Activity Level  155 non-null    int64
#  7   Stress Level             155 non-null    int64
#  8   BMI Category             155 non-null    object
#  9   Blood Pressure           155 non-null    object
#  10  Heart Rate               155 non-null    int64
#  11  Daily Steps              155 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 17.0+ KB

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
def categorize_age(Age):
    if Age>=20 and Age<30:
        return 'Young'
    elif Age>=30 and Age<40:
        return 'Adult'
    elif Age>=40 and Age<50:
        return 'Middle Age'
    elif Age>=50 and Age<60:
        return 'Old Age'
    else:
        return 'Unknown'

# %%
df['Age Group']=df['Age'].apply(categorize_age)

# %%
def stress_levels(Stress_Level):
    if Stress_Level<=4:
        return 'Light Stess'
    elif Stress_Level<=7:
        return 'Stressful'
    else:
         return 'High Stress'

# %%
df['Stress category']=df['Stress Level'].apply(stress_levels)

# %%
df.head()
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 6           7    Male   29               Teacher             6.3
# 16         17  Female   29                 Nurse             6.5
#
#     Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 3                  4                       30             8          Obese
# 4                  4                       30             8          Obese
# 5                  4                       30             8          Obese
# 6                  6                       40             7          Obese
# 16                 5                       40             7  Normal Weight
#
#    Blood Pressure  Heart Rate  Daily Steps Sleep Disorder Age Group  \
# ...

# %% [markdown]
# # No of Persons per Age Group

# %%
Persons_per_Age_Group=df.groupby("Age Group")['Person ID'].sum().sort_values(ascending=False).reset_index()
Persons_per_Age_Group
# Out:
#     Age Group  Person ID
# 0     Old Age      19044
# 1  Middle Age      17384
# 2       Adult       1434
# 3       Young         76

# %%
plt.figure(figsize=(8,8))
plt.pie(Persons_per_Age_Group['Person ID'],labels=Persons_per_Age_Group['Age Group'],autopct='%1.1f%%',startangle=90,
        colors=['lightblue','lightgreen','lightcoral','lightskyblue'])
plt.title('No of Persons per Age Group')
plt.show()

# %% [markdown]
# # Average quality of Sleep by Stress Category

# %%
avg_sleep_quality_by_stress=df.groupby('Stress category')['Quality of Sleep'].mean().reset_index()
avg_sleep_quality_by_stress
# Out:
#   Stress category  Quality of Sleep
# 0     High Stress          5.729730
# 1     Light Stess          8.172414
# 2       Stressful          6.316667

# %%
plt.figure(figsize=(6,6))
plt.bar(avg_sleep_quality_by_stress['Stress category'],avg_sleep_quality_by_stress['Quality of Sleep'])
plt.xlabel('Stress category')
plt.ylabel('Average Quality of sleep')
plt.title('Average Quality of Sleep by Stress Category')
plt.show()

# %% [markdown]
# # Distribution of People by BMI Category

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder', 'Age Group', 'Stress category'],
#       dtype='object')

# %%
bmi_category_count=df.groupby('BMI Category')['Person ID'].count().reset_index()
bmi_category_count
# Out:
#     BMI Category  Person ID
# 0         Normal         12
# 1  Normal Weight          4
# 2          Obese         10
# 3     Overweight        129

# %%
plt.figure(figsize=(6,6))
plt.pie(bmi_category_count['Person ID'], labels=bmi_category_count['BMI Category'], autopct='%1.1f%%', startangle=90,
        colors=['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue'], wedgeprops={'width': 0.4})
plt.title('Distribution of People by BMI Category')
plt.show()

# %% [markdown]
# # No of Persons per Gender

# %%
no_of_person_by_gender=df.groupby('Gender')['Person ID'].count().reset_index()
no_of_person_by_gender
# Out:
#    Gender  Person ID
# 0  Female        103
# 1    Male         52

# %%
plt.figure(figsize=(4,4))
plt.pie(no_of_person_by_gender['Person ID'],labels=no_of_person_by_gender['Gender'],autopct='%1.1f%%',startangle=90)
plt.title('No of Persons per Gender')
plt.show()

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder', 'Age Group', 'Stress category'],
#       dtype='object')

# %% [markdown]
# # Count of Gender by Occupation

# %%
gender_count_by_occupation=df.groupby(['Occupation','Gender']).size().unstack()

# %%
gender_count_by_occupation.plot(kind='bar', stacked=False,figsize=(10,6))
plt.title('Count of Gender by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Correlation between Physical Activity Level and Quality of Sleep

# %%
plt.scatter(df['Physical Activity Level'], df['Quality of Sleep'], color='purple', alpha=0.5)
plt.title('Physical Activity Level vs Quality of Sleep')
plt.xlabel('Physical Activity Level')
plt.ylabel('Quality of Sleep')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Heart Rate Vs Age

# %%
plt.scatter(df['Age'], df['Heart Rate'], color='orange', alpha=0.5)
plt.title('Heart Rate vs Age')
plt.xlabel('Age')
plt.ylabel('Heart Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Summary and Conclusion

# %% [markdown]
# # Summary:
# This dataset analysis highlights significant correlations between sleep quality, lifestyle factors, and cardiovascular health across different demographics and occupations. Key findings include:
#
# Sleep Disorders: Sleep disorders, including insomnia and sleep apnea, are prevalent among various demographic groups. Females, particularly those aged 50-59, have a high prevalence of sleep apnea (87%), while a significant proportion of males (53%) suffer from insomnia. Sleep quality varies by occupation, with Engineers, Lawyers, Nurses, Accountants, and Doctors reporting the highest sleep quality.
#
# Physical Activity & BMI: Physical activity is strongly correlated with BMI categories. Overweight and normal weight individuals tend to walk between 6,800 and 7,000 steps per day, while obese individuals walk fewer steps (around 3,000). Heart rate, however, is influenced by more than just step count, as individuals walking more than 8,000 steps per day have a lower heart rate (72 bpm) than those with fewer steps (85 bpm). Additionally, the lifestyle of Old Adults (50-59) tends to be more active than sedentary, unlike younger adults (30-49).
#
# Stress Levels: Stress levels vary by occupation, with men generally exhibiting higher stress levels than women. Occupations like Nurses and Sales Representatives show significant differences in stress levels and physical activity, with Nurses walking more steps daily (8,000) and Sales Representatives showing lower mobility (3,000 steps) and higher resting heart rates (85 bpm). High sleep quality correlates with lower stress levels.
#
# Cardiovascular Health: Blood pressure measurements show common systolic/diastolic values such as 130/85, 125/80, and 140/95, indicating varied levels of cardiovascular health across individuals.
#
# BMI Distribution: The majority of the sample falls within the normal BMI category (52%), with 40% classified as overweight and 3% as obese.
#
# # Conclusion:
# This analysis reveals the critical role of sleep, physical activity, and stress in influencing the health and wellbeing of employees. Employers can leverage these insights to create targeted interventions for improving sleep quality, reducing stress, and promoting physical activity. Such initiatives can lead to healthier, more productive employees, reducing the risks associated with poor sleep, sedentary lifestyles, and cardiovascular issues. The findings also underscore the importance of considering gender, age, and occupation-specific factors when designing wellness programs.
